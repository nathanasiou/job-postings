# %%
import pandas as pd # data processing
import matplotlib.pyplot as plt # data visualization

# %%
df = pd.read_csv('job_postings_clean.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0                  AI Electrical / Computer Engineer
# 1  Clinical Laboratory Scientist CLS , Medical Da...
# 2                              Senior Data Scientist
# 3                                  Data Scientist II
# 4                           Data Scientist / Analyst
#
#                            company   salary_updated environment  \
# 0  General Technical Services, LLC        Full-time   In-Person
# 1  Clinical Management Consultants  85225 - 135355    In-Person
# 2                        WALGREENS              NaN   In-Person
# 3                       Net2Source  114400 - 120640   In-Person
# 4                           Kforce    72800 - 93600   In-Person
#
#   location_updated
# 0      Adelphi, MD
# 1    Palo Alto, CA
# 2    Deerfield, IL
# 3  Los Angeles, CA
# 4   Juno Beach, FL

# %%
# I want to split salary into min and max, since there are wide ranges.

# if salary has '-', take first item in list as min second item in list as max, if no '-' take salary as is.
# cleaning round 2
min_list = []
max_list = []
for num in df['salary_updated']:
    
    try:
        # split each salary on '-' and take first item in list (index 0)
        min_list.append(int(str.split(str(num), '-')[0]))
    except:
        if "time" in str(num) or 'nan' in str(num) or "Contract" in str(num) or "salary" in str(num):
            min_list.append(int(0))
        else:
            min_list.append(int(num))
        
    try:
         # split each salary on '-' and take second item in list (index 1)
        max_list.append(int(str.split(str(num), '-')[1]))
    except:
        if "time" in str(num) or 'nan' in str(num) or "Contract" in str(num) or "salary" in str(num):
            max_list.append(int(0))
        else:
            max_list.append(int(num))
            
        continue
        
df['salary_min'] = min_list
df['salary_max'] = max_list

# %%
df.head()
# Out:
#                                                title  \
# 0                  AI Electrical / Computer Engineer
# 1  Clinical Laboratory Scientist CLS , Medical Da...
# 2                              Senior Data Scientist
# 3                                  Data Scientist II
# 4                           Data Scientist / Analyst
#
#                            company   salary_updated environment  \
# 0  General Technical Services, LLC        Full-time   In-Person
# 1  Clinical Management Consultants  85225 - 135355    In-Person
# 2                        WALGREENS              NaN   In-Person
# 3                       Net2Source  114400 - 120640   In-Person
# 4                           Kforce    72800 - 93600   In-Person
#
#   location_updated  salary_min  salary_max
# 0      Adelphi, MD           0           0
# 1    Palo Alto, CA       85225      135355
# 2    Deerfield, IL           0           0
# 3  Los Angeles, CA      114400      120640
# 4   Juno Beach, FL       72800       93600

# %%
# take a closer look at the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1877 entries, 0 to 1876
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             1876 non-null   object
#  1   company           1876 non-null   object
#  2   salary_updated    1394 non-null   object
#  3   environment       1877 non-null   object
#  4   location_updated  1870 non-null   object
#  5   salary_min        1877 non-null   int64
#  6   salary_max        1877 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 102.8+ KB

# %%
df.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275 entries, 0 to 1874
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             274 non-null    object
#  1   company           274 non-null    object
#  2   salary_updated    218 non-null    object
#  3   environment       275 non-null    object
#  4   location_updated  274 non-null    object
#  5   salary_min        275 non-null    int64
#  6   salary_max        275 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 17.2+ KB

# %%
# basic stats
df.describe()
# Out:
#          salary_min    salary_max
# count  1.877000e+03  1.877000e+03
# mean   6.073812e+04  7.991876e+04
# std    2.538591e+05  2.960700e+05
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    1.100000e+05  1.560000e+05
# max    1.070368e+07  1.239472e+07

# %%
df[df["salary_min"]>0].drop_duplicates().sort_values(by = "salary_min", ascending = False).head(10)
# Out:
#                                                   title  \
# 910               Computer Vision AI Software Developer
# 71                                       Data Scientist
# 775                              Director, Data Science
# 1544                                     Data Scientist
# 1140                 Remote- Statistical Project Leader
# 323                                      Data Scientist
# 1486                 Senior Data Scientist (2 openings)
# 1725        Pricing Actuary Predictive Modeler - REMOTE
# 1784                                 Data Scientist III
# 491   Senior Vice President / Senior Data Architect/...
#
#                        company       salary_updated environment  \
# 910                Robert Half  10703680 - 12394720   In-Person
# 71                   Cartwheel              200000       Remote
# 775            RUE GILT GROUPE     200000 - 250000       Hybrid
# 1544  Johns Hopkins University               198110   In-Person
# 1140                    Sanofi              180687       Remote
# 323                     withco     180000 - 200000    In-Person
# 1486                   current     180000 - 205000    In-Person
# 1725                DW Simpson              178000       Remote
# 1784              Uber Freight              171067    In-Person
# 491                       Citi     170880 - 256320    In-Person
#
#        location_updated  salary_min  salary_max
# 910        Evanston, IL    10703680    12394720
# 71               Remote      200000      200000
# 775        New York, NY      200000      250000
# 1544      Baltimore, MD      198110      198110
# 1140    Bridgewater, NJ      180687      180687
# 323        New York, NY      180000      200000
# 1486       New York, NY      180000      205000
# 1725       New York, NY      178000      178000
# 1784  San Francisco, CA      171067      171067
# 491      Rutherford, NJ      170880      256320

# %%
df.drop_duplicates().sort_values(by = "salary_max", ascending = False).head(10)
# Out:
#                                                   title  \
# 910               Computer Vision AI Software Developer
# 425   Senior Data Scientist - E-commerce Product Ana...
# 491   Senior Vice President / Senior Data Architect/...
# 775                              Director, Data Science
# 923                               Senior Data Scientist
# 1772                                  Sr Data Scientist
# 469                                      Data Scientist
# 1380                  Lead Statistical (SAS) Programmer
# 1486                 Senior Data Scientist (2 openings)
# 1593                              Senior Data Scientist
#
#                            company       salary_updated environment  \
# 910                    Robert Half  10703680 - 12394720   In-Person
# 425                         TikTok     158000 - 295000    In-Person
# 491                           Citi     170880 - 256320    In-Person
# 775                RUE GILT GROUPE     200000 - 250000       Hybrid
# 923                      Microsoft     112000 - 218400    In-Person
# 1772   Marriott International, Inc     117666 - 217498    In-Person
# 469   Management Science Solutions     104082 - 210832    In-Person
# 1380                       Redbock      156000 - 208000      Remote
# 1486                       current     180000 - 205000    In-Person
# 1593                 Pie Insurance     150000 - 205000       Remote
#
#      location_updated  salary_min  salary_max
# 910      Evanston, IL    10703680    12394720
# 425       Seattle, WA      158000      295000
# 491    Rutherford, NJ      170880      256320
# 775      New York, NY      200000      250000
# 923       Redmond, WA      112000      218400
# 1772  Bethesda, MD \n      117666      217498
# 469     Chantilly, VA      104082      210832
# 1380           Remote      156000      208000
# 1486     New York, NY      180000      205000
# 1593           Remote      150000      205000
